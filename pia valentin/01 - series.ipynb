# %% [markdown]
# # Ejercicios series

# %% [markdown]
# 1. Crea una serie de pandas utilizando un diccionario con las siguientes etiquetas y valores:
#
#     ```python
#     diccionario = {"a": 10, "b": 20, "c": 30, "d": 40, "e": 50}
#     ```
#
#     Asigna esta serie a la variable serie.

# %%
import pandas as pd
diccionario = {"a": 10, "b": 20, "c": 30, "d": 40, "e": 50}
pandasDic = pd.Series(diccionario)

print(pandasDic)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# 2. Utilizando métodos de acceso por etiqueta y posición, extrae y muestra el valor de las siguientes posiciones y etiquetas:
#
#    - Posición 2
#    - Etiqueta "d"
#    - Etiquetas "b" y "e"

# %%
print(pandasDic.iloc[2])
print(pandasDic["d"])
print(pandasDic.loc[["b","e"]])
# Out:
# 30
# 40
# b    20
# e    50
# dtype: int64

# %% [markdown]
# 3. Utiliza el método `iloc` para seleccionar los primeros 3 elementos de la serie y el método `loc` para seleccionar los elementos desde "b" hasta "d"

# %%
print(pandasDic.iloc[:3])
print(pandasDic.loc["b":"d"])
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# 1. Dada la serie creada en el Ejercicio 1, asigna un nuevo índice a la serie usando el siguiente conjunto de etiquetas: ['A', 'B', 'C', 'D', 'E'].

# %%
indices = ['A', 'B', 'C', 'D', 'E']
pandasDic.index = indices
print(pandasDic)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# 2. Encuentra el valor mínimo y máximo de la serie y sus índices correspondientes utilizando los métodos `min()`, `max()`, `idxmin()`, e `idxmax()`.

# %%
print(f"Minimo = {min(pandasDic.values)}")
print(f"Maximo = {max(pandasDic.values)}")
print(f"Indice maximo = {pandasDic.idxmax()}")
print(f"Indice minimo = {pandasDic.idxmin()}")
# Out:
# Minimo = 10
# Maximo = 50
# Indice maximo = E
# Indice minimo = A

# %% [markdown]
# 3. Calcula la media, la suma, y el número de elementos únicos en la serie.

# %%
print(f"Media = {pandasDic.mean()}")
print(f"Suma = {pandasDic.sum()}")
print(f"Unicos = {pandasDic.unique()}")
# Out:
# Media = 30.0
# Suma = 150
# Unicos = [10 20 30 40 50]

# %% [markdown]
# 1. Dada la serie creada en el Ejercicio 1 con los nuevos índices asignados en el Ejercicio 2, filtra todos los elementos que sean mayores que 25 y menores que 45.

# %%
print(pandasDic[(pandasDic > 25) & (pandasDic < 45)])
# Out:
# C    30
# D    40
# dtype: int64

# %% [markdown]
# 2. Filtra los elementos que sean mayores que la media de la serie.

# %%
mediaSerie = pandasDic.mean()
print(pandasDic[pandasDic > mediaSerie])
# Out:
# D    40
# E    50
# dtype: int64

# %% [markdown]
# 3. Verifica si las etiquetas "C" y "F" existen en la serie, e imprime el resultado.

# %%
if pandasDic.get("C") and pandasDic.get("F"):
    print(pandasDic.get("C"))
    print(pandasDic.get("F"))
else:
    print("No hay etiquetas")

# %% [markdown]
# 1. Crea una nueva serie con los siguientes valores: [1.5, 2.5, 3.5, 4.5, 5.5] y asigna índices ['a', 'b', 'c', 'd', 'e'].

# %%
serie = pd.Series([1.5, 2.5, 3.5, 4.5, 5.5])
serie.index = ['a', 'b', 'c', 'd', 'e']
print(serie)
# Out:
# a    1.5
# b    2.5
# c    3.5
# d    4.5
# e    5.5
# dtype: float64

# %% [markdown]
# 2. Multiplica todos los elementos de la serie por 2 y asigna el resultado a una nueva serie.

# %%
nuevaSerie = serie * 2
print(nuevaSerie)
# Out:
# a     3.0
# b     5.0
# c     7.0
# d     9.0
# e    11.0
# dtype: float64

# %% [markdown]
# 3. Crea otra serie de pandas con valores de texto ['apple', 'banana', 'cherry', 'date', 'elderberry'] e índices ['A', 'B', 'C', 'D', 'E'].

# %%
otraSerie = pd.Series(['apple', 'banana', 'cherry', 'date', 'elderberry'],index=['A', 'B', 'C', 'D', 'E'])
print(otraSerie)
# Out:
# A         apple
# B        banana
# C        cherry
# D          date
# E    elderberry
# dtype: str

# %% [markdown]
# 4. Utiliza métodos específicos de cadenas (str) para realizar las siguientes operaciones en la serie de texto:
#
# - Convierte todos los elementos a mayúsculas.
# - Reemplaza las vocales 'a' por 'o' en todos los elementos.

# %%
otraSerie = otraSerie.str.upper()
print(otraSerie)
otraSerie = otraSerie.str.replace('A','o')
print(otraSerie)
# Out:
# A         APPLE
# B        BANANA
# C        CHERRY
# D          DATE
# E    ELDERBERRY
# dtype: str
# A         oPPLE
# B        BoNoNo
# C        CHERRY
# D          DoTE
# E    ELDERBERRY
# dtype: str

# %% [markdown]
# 1. Crea una serie con los valores [100, 200, 300, 400] e índices ['x', 'y', 'z', 'w'].
#
# 2. Reindexa la serie para que los nuevos índices sean ['a', 'b', 'c', 'd', 'e']. Los nuevos índices que no tienen valores correspondientes deben tener un valor nulo (NaN).
#
# 3. Llena los valores nulos con el valor 0.
#
# 4. Elimina todos los valores nulos de la serie inicial (sin llenar los nulos).

# %%
serie = pd.Series([100,200,300,400],index=["x","y","z","w"])
nuevoIndex = ['a', 'b', 'c', 'd', 'e']
serie = serie.reindex(nuevoIndex)
print(serie)

print(serie.fillna(0))
print(serie.dropna())
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64
# a    0.0
# b    0.0
# c    0.0
# d    0.0
# e    0.0
# dtype: float64
# Series([], dtype: float64)

# %% [markdown]
# 1. Utilizando la serie creada en el Ejercicio 1, obtén las primeras 3 filas y las últimas 2 filas de la serie.
#
# 2. Genera estadísticas descriptivas de la serie utilizando el método describe().
#
# 3. Obtén el conteo de valores, media, desviación estándar, mínimo, máximo, y los percentiles del 25%, 50%, y 75%.

# %%
print(f"{pandasDic.head(3)} \n{pandasDic.tail(2)}" )
print(pandasDic.describe())
# Out:
# A    10
# B    20
# C    30
# dtype: int64
# D    40
# E    50
# dtype: int64
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %% [markdown]
# 1. Crea una serie con valores [2, 4, 6, 8, 10] e índices ['a', 'b', 'c', 'd', 'e'].
#
# 2. Aplica una función que eleve cada valor de la serie al cuadrado utilizando el método apply().
#
# 3. Crea un diccionario de mapeo {2: 'two', 4: 'four', 6: 'six', 8: 'eight', 10: 'ten'} y utiliza el método map() para reemplazar los valores de la serie con sus correspondientes textos.

# %%
serie =  pd.Series([2, 4, 6, 8, 10],index=['a', 'b', 'c', 'd', 'e'])  

print(serie.apply(lambda value: value*value))

serie = serie.map({2: 'two', 4: 'four', 6: 'six', 8: 'eight', 10: 'ten'})
print(serie)
# Out:
# a      4
# b     16
# c     36
# d     64
# e    100
# dtype: int64
# a      two
# b     four
# c      six
# d    eight
# e      ten
# dtype: str

# %% [markdown]
# Crea una serie de 10 elementos, que contenga números enteros aleatorios del 70 al 100, que representan las notas mensuales
# de los examenes de esta asignatura para un alumno. Configura el índice para que sean los nombres de los meses, comenzando en septiembre y terminando en junio.
#
# En base a esta serie, responde las siguientes preguntas:
# - ¿Cuál es la nota media del estudiante en las pruebas durante todo el año?
# - ¿Cuál es la nota media del estudiante en las pruebas durante la primera mitad del año (es decir, los primeros cinco meses)?
# - ¿Cuál es la nota media del estudiante en las pruebas durante la segunda mitad del año?
# - ¿El estudiante mejoró sus notas en la segunda mitad? Si es así, ¿en cuánto?

# %%
import numpy as np
serieNotas = pd.Series(np.random.randint(70,101,size = 10),index="septiembre octubre noviembre diciembre enero febrero marzo abril mayo junio".split(" "))
 
print(serieNotas)
mediaAnio = serieNotas.mean()
mediaAnio1 = serieNotas.head(5).mean()
mediaAnio2 = serieNotas.tail(5).mean()
 
print(f"Media año {mediaAnio}")
print(f"Media primera parte año {mediaAnio1}")
print(f"Media segunda parte año {mediaAnio2}")
if mediaAnio2 > mediaAnio1:
    print(f"El alumno mejoro {mediaAnio2 - mediaAnio1} puntos")
# Out:
# septiembre    75
# octubre       94
# noviembre     86
# diciembre     84
# enero         93
# febrero       94
# marzo         96
# abril         78
# mayo          89
# junio         88
# dtype: int32
# Media año 87.7
# Media primera parte año 86.4
# Media segunda parte año 89.0
# El alumno mejoro 2.5999999999999943 puntos

# %% [markdown]
# Cuando estaba en el instituto y en la universidad, nuestros profesores a veces daban exámenes que eran extremadamente difíciles. En lugar de suspender a la mayor parte de la clase, a veces "escalaban" las notas de los exámenes. Es decir, asumían que la puntuación media de la prueba debería ser 85. Por lo tanto, calculaban la diferencia entre nuestra media real y esta media ideal, y luego sumaban puntos a cada una de nuestras notas.
#
# Para este ejercicio, quiero que generes 10 puntuaciones de exámenes entre 40 y 60 usando un índice, comenzando en septiembre y terminando en junio. Encuentra la media de las puntuaciones y suma la diferencia entre la media y 85 para cada una de las puntuaciones.

# %%
serieNotas = pd.Series(np.random.randint(40,61,size = 10),index="septiembre octubre noviembre diciembre enero febrero marzo abril mayo junio".split(" "))

media = serieNotas.mean()
print(serieNotas + (85 - media))
# Out:
# septiembre    87.2
# octubre       87.2
# noviembre     87.2
# diciembre     88.2
# enero         77.2
# febrero       89.2
# marzo         89.2
# abril         82.2
# mayo          89.2
# junio         73.2
# dtype: float64

# %% [markdown]
# Genera 10 números enteros aleatorios entre 0 - 100. Crea una serie que contenga los dígitos de las decenas de esos números. Por ejemplo, si nuestra serie contiene 10, 20, 30, queremos una serie con 1, 2, 3.

# %%
serieNotas = pd.Series(np.random.randint(100,size = 10) / 10)
print(serieNotas)
# Out:
# 0    6.2
# 1    8.2
# 2    7.9
# 3    5.9
# 4    0.9
# 5    7.5
# 6    5.6
# 7    0.5
# 8    7.6
# 9    4.7
# dtype: float64
